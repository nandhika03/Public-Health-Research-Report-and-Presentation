# %%
import pandas as pd

# Load the uploaded influenza dataset
file_path = "/content/StateDatabyWeekforMap_2018-19week40-39.csv"
flu_df = pd.read_csv(file_path)

# Display the first few rows and column names
flu_df.head(), flu_df.columns.tolist()
print(flu_df.head(2))
# Out:
#   STATENAME                                                URL  \
# 0   Alabama                         http://adph.org/influenza/
# 1    Alaska  http://dhss.alaska.gov/dph/Epi/id/Pages/influe...
#
#                          WEBSITE ACTIVITY LEVEL ACTIVITY LEVEL LABEL  \
# 0         Influenza Surveillance        Level 2              Minimal
# 1  Influenza Surveillance Report        Level 1              Minimal
#
#        WEEKEND  WEEK   SEASON
# 0  Oct-06-2018    40  2018-19
# 1  Oct-06-2018    40  2018-19

# %%
# !pip install censusdata
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.6/26.6 MB 47.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for censusdata: filename=CensusData-1.15.post1-py3-none-any.whl size=28205744 sha256=cc40ea7b693d5c0540f33b280a3cefad4e2b1974d2f8fc915285de9c7fdf59e9
#   Stored in directory: /root/.cache/pip/wheels/7c/5b/55/834c5472b44ab5688be29f6009667601fbc13f38cff9dd36e6
# Successfully built censusdata
# ...

# %%
# !pip install noaa-sdk

# %%
# !pip install census us geopandas matplotlib

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from census import Census
from us import states

# Set your API key here
CENSUS_KEY = "6ca23ef1d66ae4bc91a312d4e9e49ed7a1873d19"
c = Census(CENSUS_KEY)

# %% [markdown]
# ## Get ACS Poverty + Population Data for Michigan
# We’ll pull:
#
# C17002_001E: Total population with a poverty ratio
#
# C17002_002E: Population < 0.5 poverty ratio
#
# C17002_003E: Population between 0.5–0.99
#
# B01003_001E: Total population

# %%
mi_census = c.acs5.state_county_tract(
    fields=('NAME', 'C17002_001E', 'C17002_002E', 'C17002_003E', 'B01003_001E'),
    state_fips=states.MI.fips,
    county_fips="*",
    tract="*",
    year=2019
)

mi_df = pd.DataFrame(mi_census)
mi_df.head()
# Out:
#                                            NAME  C17002_001E  C17002_002E  \
# 0     Census Tract 28, Genesee County, Michigan       1626.0        627.0
# 1     Census Tract 38, Genesee County, Michigan       1258.0        155.0
# 2  Census Tract 219.01, Ottawa County, Michigan       4530.0         68.0
# 3  Census Tract 219.02, Ottawa County, Michigan       8058.0         34.0
# 4  Census Tract 220.01, Ottawa County, Michigan       5404.0        110.0
#
#    C17002_003E  B01003_001E state county   tract
# 0        413.0       2693.0    26    049  002800
# 1        394.0       1258.0    26    049  003800
# 2        137.0       4531.0    26    139  021901
# 3        220.0       8119.0    26    139  021902
# 4        227.0       5689.0    26    139  022001
